# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
arr1= np.array([[1,2,3], [4,5,6]])
arr2 = np.random.rand(3,3)
arr3 = np.zeros((4,4))

# %%
# it will save arr ,save hote hi arr1, arr2, arr3 aa jaayega folder me 
np.save('arr1.npy', arr1)
np.save('arr2.npy', arr2)
np.save('arr3.npy', arr3)

# %%
# ab ye array ko folder se load krwane ke liye 
loaded_arr1 = np.load('arr1.npy')
print(loaded_arr1)
# Out:
# [[1 2 3]
#  [4 5 6]]
